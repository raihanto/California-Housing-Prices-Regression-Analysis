# %% [markdown]
# <a href="https://colab.research.google.com/github/raihanto/California-Housing-Prices-Regression-Analysis/blob/main/%20California-Housing-Prices-Regression-Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Introduction**

# %% [markdown]
# California adalah salah satu negara bagian yang tergabung dalam negara the United States of America. Pada masa The Gold Rush atau Demam Emas California, ribuan pekerja imigran baik domestik maupun mancanegara berbondong-bondong datang ke California untuk bekerja di tambang-tambang yang pada saat itu merupakan tulang punggung perekonomian California. Setelah surutnya pertambangan emas di California, penduduk yang menetap serta imigran yang masih terus berdatangan mengambil peran di berbagai bidang seiring dengan adanya diversifikasi ekonomi, contohnya pertanian, industri, perikanan, kehutanan, pabrik pesawat terbang,galangan kapal, pariwisata, rekreasi dan bahkan industri hiburan.
#
# Dengan lebih dari 39 juta penduduk per tahun 2020, California merupakan negara bagian dengan populasi terbesar di US dan apabila berdiri menjadi negara terpisah, California dapat menjadi negara ke-34 terpadat di dunia. Saat ini, hampir 95 persen orang California tinggal di wilayah metropolitan, menjadikan California sebagai negara bagian paling urban di US maupun dunia. Sebagian besar analis dan *forecaster* setuju bahwa California akan menjadi rumah bagi  lebih dari 46 juta penduduk di tahun-tahun mendatang. Tren ini akan terus berlanjut dengan ramalan populasi California pada tahun 2050 bisa sedikitnya 50 juta atau sebanyak 70 juta.
#
# Tren peningkatan penduduk California ini tentu berimbas kepada tingkat kebutuhan dan ketersediaan bangunan tempat tinggal atau perumahan yang seringkali disebut sebagai *real estate*. Adapun efek lanjutan dari *supply and demand* adalah fluktuasi dan keragaman harga properti *real estate* tersebut yang sangat bergantung kepada kondisi, feature-feature yang ada, kelebihan, kekurangan, serta banyak aspek-aspek lainnya. Mengetahui harga rumah atau tempat tinggal di California akan menjadi hal yang sangat penting untuk berbagai pihak, terutama kepada penduduk dan populasi yang akan bermukim atau sudah bermukim di California mengingat jenis dan rumah di California sangat beragam sesuai dengan kebutuhan dan kemampuan penduduk.
#
# **Sources**:
#
# *   California State Guide. https://guides.loc.gov/california-state-guide
# *   California State Homepage. https://www.ca.gov/
# *   Urban Strategy for California. https://opr.ca.gov/docs/20190325-urban_strategy-ocr.pdf
# *   California Projected Urban Growth. https://koordinates.com/layer/670-california-2020-projected-urban-growth/
# *   California Real Estate. https://www.sacbee.com/news/business/real-estate-news/
# *   California Real Estate & Housing Prices News & Updates. https://slate.com/business/2022/10/housing-prices-real-estate-interest-rates-federal-reserve-california.html

# %% [markdown]
# # **Problem Understanding**

# %% [markdown]
# Dalam bagian ini, fokus utama dari problem akan dijabarkan dimulai dari pernyataan masalah atau *problem statement*, goals atau tujuan dari riset, pendekatan analitis yang dilakukan, serta kegunaan dari riset ini secara menyeluruh.

# %% [markdown]
# ## **Problem Statement**

# %% [markdown]
# Sebagaimana telah dijelaskan sebelumnya, salah satu aspek yang menjadi tantangan bagi penduduk yang akan bermukim atau sudah bermukim di California adalah mengetahui harga rumah atau tempat tinggal di California. Maka dari itu, **diperlukan sebuah acuan untuk menentukan harga yang tepat bagi suatu rumah atau bangunan tempat tinggal sesuai dengan aspek, fitur, serta spesifikasi yang ada**.

# %% [markdown]
# ## **Goals**

# %% [markdown]
# Berdasarkan permasalahan tersebut, akan dibuatkan **sebuah model yang dapat memprediksi harga sebuah rumah atau properti berdasarkan aspek, fitur, serta spesifikasi yang dimiliki oleh properti tersebut**. Harga yang dihasilkan oleh model ini akan mengikuti suatu standar atau sistem yang dapat menjadi referensi bagi pihak-pihak yang membutuhkan **dengan tujuan untuk mempermudah pengambilan keputusan dalam melakukan transaksi penjualan dan pembelian**.

# %% [markdown]
# ## **Analytical Approach**

# %% [markdown]
# Pendekatan yang dilakukan adalah membuat model yang dapat memprediksi harga sebuah rumah sesuai dengan parameter serta fitur-fitur yang ada pada data. Analisa korelasi akan dilakukan terhadap fitur-fitur yang ada dan akan ditentukan spesifikasi apa saja dari suatu properti yang dapat berpengaruh terhadap harga tersebut. Dari hasil tersebut, dapat dibuat berbagai macam model regresi yang bertujuan untuk menentukan harga, dan melalui model-model tersebut ditentukan model terbaik yang memberikan metrics terbaik yang akan digunakan sebagai final model.

# %% [markdown]
# ## **Research Utilization**

# %% [markdown]
# Secara garis besar, *raw data* seperti yang telah diberikan serta model yang akan dibuat dapat dipergunakan dalam berbagai macam aspek dan dapat dimanfaatkan oleh berbagai pihak. Model yang diberikan dapat dijadikan acuan bagi **penjual rumah, *realtor*, *investor*, agen *real estate* maupun konsultan *real estate*** untuk menentukan harga suatu rumah atau bangunan sesuai dengan fitur, spesifikasi, kelebihan, dan kekurangan yang ada. Sebaliknya, model juga dapat menjadi **bahan pertimbangan pembeli, *investor*, dan pihak-pihak lain yang berkeinginan membeli suatu rumah** atau properti tertentu dengan alasan yang sama.

# %% [markdown]
# ## **Metrics evaluation**

# %% [markdown]
# Evaluasi metrik yang akan digunakan adalah RMSE, MAE, dan MAPE. RMSE adalah nilai rata-rata akar kuadrat dari error, MAE adalah rata-rata nilai absolut dari error, sedangkan MAPE adalah rata-rata persentase error yang dihasilkan oleh model regresi. Semakin kecil nilai RMSE, MAE, dan MAPE yang dihasilkan, berarti model semakin akurat dalam memprediksi target atau dependent variable sesuai dengan fitur yang digunakan.

# %% [markdown]
# # **Data** **Preparation**

# %% [markdown]
# Untuk menjawab pernyataan masalah seperti yang telah dijelaskan di atas, dataset yang telah ada akan dipersiapkan, dianalisa, dan dilakukan pemrosesan sebelum dilakukan modelling. Persiapan dan pemrosesan data meliputi pemahaman data atau *data understanding*, EDA atau *Exploratory Data Analysis*, pembersihan data atau *data cleaning* serta langkah-langkah lainnya yang sangat penting dalam persiapan data. Langkah pertama yang perlu dilakukan yaitu mempersiapkan *libraries* dan *tools* yang dibutuhkan.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Langkah berikutnya yang dilakukan yaitu melakukan import dan read dataset dari direktori local files. Dataset awal dapat di-akses [di hyperlink ini.](https://drive.google.com/file/d/1NJ7DsgZ3zIdZWTz17RQWgbtDBuk1JVg3/view) Contoh data 5 teratas dan 5 terbawah ditampilkan seperti berikut ini:

# %%
df = pd.read_csv('data_california_house.csv')
display(df.head(),df.tail())
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -119.79     36.73                52.0        112.0            28.0
# 1    -122.21     37.77                43.0       1017.0           328.0
# 2    -118.04     33.87                17.0       2358.0           396.0
# 3    -118.28     34.06                17.0       2518.0          1196.0
# 4    -119.81     36.73                50.0        772.0           194.0
#
#    population  households  median_income ocean_proximity  median_house_value
# 0       193.0        40.0         1.9750          INLAND             47500.0
# 1       836.0       277.0         2.2604        NEAR BAY            100000.0
# 2      1387.0       364.0         6.2990       <1H OCEAN            285800.0
# 3      3051.0      1000.0         1.7199       <1H OCEAN            175000.0
# 4       606.0       167.0         2.2206          INLAND             59200.0
# ...

# %% [markdown]
# ## **Data General Understanding**

# %% [markdown]
# Data yang telah diberikan merupakan **data terkait median harga rumah rata-rata untuk distrik California yang berasal dari sensus yang dilakukan pada tahun 1990**. Seperti telah diperlihatkan pada display di atas, dataset yang diberikan memiliki beberapa informasi penting. Kolom-kolom yang terdapat di dataset adalah sebagai berikut:
#
# 1. **longitude**: Titik koordinat pada garis bujur, semakin besar angka *longitude* maka semakin ke barat titik tersebut.
# 2. **latitude**: Titik koordinat pada garis lintang, semakin besar angka *latitude* maka semakin ke utara titik tersebut.
# 3. **housing_median_age**: Angka median dari umur bangunan dalam radius satu block, semakin besar angka *housing_median_age* maka semakin tua bangunan tersebut.
# 4. **total_rooms**: Jumlah ruangan dalam radius satu block.
# 5. **total_bedrooms**: Jumlah kamar tidur dalam radius satu block.
# 6. **population**: Jumlah populasi yang bermukim dalam radius satu block
# 7. **households**: Jumlah rumah tangga (di Indonesia dapat diartikan menjadi jumlah Kartu Keluarga / Kepala Keluarga) yang tinggal dalam satu bangunan dalam radius satu block
# 8. **median_income**: Angka median dari pendapatan tiap *household* / satuan rumah tangga dihitung kumulatif dalam radius satu block (dalam satuan puluhan ribu US Dollar)
# 9. **ocean_proximity**: Lokasi atau jarak rumah relatif terhadap laut atau pesisir
# 10. **median_house_value**: Angka median dari nilai rumah atau bangunan untuk tiap *household* atau satuan rumah tangga dalam radius satu block (dalam satuan US Dollar)
#
# Perlu diperhatikan bahwa *block* di US adalah satuan yang secara informal sering digunakan dalam perhitungan jarak atau area. *Block* dapat diartikan sebagai area persegi yang dikelilingi oleh jalan-jalan, biasanya berisi beberapa bangunan. Di kota-kota besar Indonesia, *block* dapat diekuivalensikan dengan satuan RT atau beberapa *gang*.
#
# Berikut merupakan informasi general terkait dengan dataset yang akan dianalisa:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14448 entries, 0 to 14447
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           14448 non-null  float64
#  1   latitude            14448 non-null  float64
#  2   housing_median_age  14448 non-null  float64
#  3   total_rooms         14448 non-null  float64
#  4   total_bedrooms      14311 non-null  float64
#  5   population          14448 non-null  float64
#  6   households          14448 non-null  float64
#  7   median_income       14448 non-null  float64
#  8   ocean_proximity     14448 non-null  object
#  9   median_house_value  14448 non-null  float64
# dtypes: float64(9), object(1)
# memory usage: 1.1+ MB

# %%
display(df.describe(), df.describe(include='object'))
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  14448.000000  14448.000000        14448.000000  14448.000000
# mean    -119.566647     35.630093           28.618702   2640.132683
# std        2.006587      2.140121           12.596694   2191.612441
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1451.000000
# 50%     -118.490000     34.260000           29.000000   2125.000000
# 75%     -118.000000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  32627.000000
#
#        total_bedrooms    population    households  median_income  \
# count    14311.000000  14448.000000  14448.000000   14448.000000
# mean       538.260709   1425.157323    499.508929       3.866667
# std        423.577544   1149.580157    383.098390       1.891158
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %% [markdown]
# Kemudian, dapat dilihat juga keberagaman data terutama terkait dengan banyaknya *unique value*:

# %%
listData= []
for col in df.columns :
    listData.append( [col, df[col].nunique(), df[col].unique()])

tabelDesc = pd.DataFrame(columns=['Column Description', 'Number of Unique Value', 'Unique Value Description'],
                     data=listData)
tabelDesc
# Out:
#    Column Description  Number of Unique Value  \
# 0           longitude                     806
# 1            latitude                     836
# 2  housing_median_age                      52
# 3         total_rooms                    5227
# 4      total_bedrooms                    1748
# 5          population                    3498
# 6          households                    1649
# 7       median_income                    9797
# 8     ocean_proximity                       5
# 9  median_house_value                    3548
#
#                             Unique Value Description
# 0  [-119.79, -122.21, -118.04, -118.28, -119.81, ...
# 1  [36.73, 37.77, 33.87, 34.06, 33.8, 33.81, 38.6...
# 2  [52.0, 43.0, 17.0, 50.0, 11.0, 14.0, 6.0, 10.0...
# 3  [112.0, 1017.0, 2358.0, 2518.0, 772.0, 10535.0...
# 4  [28.0, 328.0, 396.0, 1196.0, 194.0, 1620.0, 14...
# 5  [193.0, 836.0, 1387.0, 3051.0, 606.0, 4409.0, ...
# 6  [40.0, 277.0, 364.0, 1000.0, 167.0, 1622.0, 14...
# ...

# %% [markdown]
# Secara garis besar, dapat disimpulkan dari Data Frame yang telah ditunjukkan di atas bahwa:
#
# 1. Dataset yang digunakan dalam analisis ini memiliki 10 kolom dan 14448 baris.
# 2. Kolom `longitude` dan `latitude` merupakan data spasial yang apabila digabungkan akan menunjukkan letak koordinat suatu titik.
# 3. Kolom `ocean_proximity` merupakan data kategorikal yang membagi data-data yang ada dalam dataset di atas menjadi beberapa kategori bergantung kepada posisi dari koordinat relatif terhadap kedekatan dengan pesisir atau garis pantai.
# 4. Kolom `housing_median_age`, `total_rooms`, `total_bedrooms`, `households`,`population`, `median_income` dan `median_house_value` adalah data numerikal positif dengan rentang tak terbatas yang menunjukkan atribut masing-masing dari sampel.

# %% [markdown]
# ## **Exploratory Data Analysis**

# %% [markdown]
# **Exploratory Data Analysis** atau **EDA** dilakukan untuk menyelidiki data lebih lanjut serta melihat secara detail gagasan utama atau *insights* yang mungkin terkandung pada data. EDA dapat memberikan pemahaman dasar tentang distribusi data, nilai nol dari data atau *missing values*, visualisasi beberapa aspek dari data, dan banyak lagi.

# %% [markdown]
# **Housing Location by Coordinates & Ocean Proximity**
#
# Sebagai visualisasi dasar terkait data yang ada, dapat digunakan scatter plot untuk melihat penyebaran titik koordinat dengan menggunakan kolom *longitude* dan *latitude*. *Alpha feature* pada grafik pertama digunakan untuk menunjukkan kepadatan jumlah properti yang ada pada data. Pada grafik kedua, digunakan warna *pastel* untuk membedakan kategori rumah berdasarkan kolom *Ocean Proximity*. Hasil scatter plot identik dengan peta negara bagian California dapat dilihat sebagai berikut:

# %%
plt.figure(figsize=(10, 10))
sns.scatterplot(df['longitude'], df['latitude'], alpha=0.3).set_title('Housing Location')

plt.figure(figsize=(10, 10))
sns.scatterplot(df['longitude'], df['latitude'], hue=df['ocean_proximity'], palette='pastel').set_title('House Location Relative to Ocean Proximity')
# Out:
# Text(0.5, 1.0, 'House Location Relative to Ocean Proximity')

# %% [markdown]
# **Distribution of Each Parameter**
#
# Berikut merupakan visualisasi dasar terkait distribusi ata yang ada. Pairplot menunjukkan sebagian besar data merupakan *right-skewed data* (kecuali longitude dan latitude) yang menandakan sebagian besar kolom tidak terdistribusi normal. Secara awam, dapat dilihat ada anomali atau *outliers* di *housing_median_age* dan *median_house_value*.

# %%
df.hist(bins=50,figsize=(15,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fa6f1cb5750>,
# ...
#       dtype=object)

# %% [markdown]
# **Median House Value Data Distribution & Location**

# %% [markdown]
# Berikut merupakan visualisasi terkait distribusi *median house value* agar dapat dilihat lebih jelas daripada sebelumnya. Grafik kedua menunjukkan *median house value* relatif terhadap lokasi koordinatnya (penggabungan longitude dan latitude akan membentuk koordinat).

# %%
plt.figure(figsize=(8, 8))
sns.distplot(df['median_house_value'])
plt.title('Median House Value Distribution Plot', size=16, weight='bold');

plt.figure(figsize=(10, 10))
sns.scatterplot(df['longitude'], df['latitude'], hue=df['median_house_value'], palette='flare').set_title('Median House Value by Location')
# Out:
# Text(0.5, 1.0, 'Median House Value by Location')

# %% [markdown]
# Dapat dilihat dari grafik kedua bahwa rumah-rumah dengan harga yang lebih tinggi banyak berlokasi lebih dekat dengan pesisir. Secara awam, terlihat bahwa semakin dekat pesisir maka harga rumah akan semakin meningkat. Namun, hal ini perlu dibuktikan dan dianalisa lebih lanjut dalam bagian-bagian riset berikutnya.

# %% [markdown]
# **Median Income by Location**
#
# Berikut adalah grafik visualisasi persebaran *Median Income* sesuai dengan koordinatnya. Secara awam, dapat dilihat bahwa persebaran *median income* cukup serupa dengan persebaran *median house value* dimana lokasi-lokasi dengan *median house value* tinggi maka *median income per households* disekitarnya juga ikut tinggi. Hal ini akan dianalisa lebih lanjut dalam riset ini.

# %%
plt.figure(figsize=(10, 10))
sns.scatterplot(df['longitude'], df['latitude'], hue=df['median_income'], palette='flare').set_title('Median Income by Location')
# Out:
# Text(0.5, 1.0, 'Median Income by Location')

# %% [markdown]
# **Housing Median Age by Location**
#
# Berikut adalah grafik visualisasi persebaran *Housing Median Age* sesuai dengan koordinatnya. Berbeda dengan grafik-grafik sebelumnya, *Housing Median Age* tersebar lebih acak terlepas dari *income*, kedekatan dengan pesisir, dan aspek-aspek yang telah disebutkan sebelumnya.

# %%
plt.figure(figsize=(10, 10))
sns.scatterplot(df['longitude'], df['latitude'], hue=df['housing_median_age'], palette='flare').set_title('Housing Median Age Location')
# Out:
# Text(0.5, 1.0, 'Housing Median Age Location')

# %% [markdown]
# **House Count by Ocean Proximity**
#
# Pada bagian ini, jumlah properti atau

# %%
display(df['ocean_proximity'].value_counts())

sns.catplot(data=df, x='ocean_proximity', kind='count', palette='pastel')
plt.xticks(rotation=45)
plt.show()
# Out:
# <1H OCEAN     6369
# INLAND        4576
# NEAR OCEAN    1879
# NEAR BAY      1622
# ISLAND           2
# Name: ocean_proximity, dtype: int64

# %% [markdown]
# **Initial Correlation**
#
# Berikut adalah grafik visualisasi korelasi awal untuk data-data numerikal yang terdapat pada *initial dataframe* sebelum dilakukan langkah langkah berikutnya.

# %%
plt.figure(figsize=(15, 12))
corr = df.corr(method='spearman')
sns.heatmap(corr, annot=True, fmt='.2f', cmap='crest', square=True, linewidths=.5)
plt.title('Correlation Matrix', size=15, weight='bold');

# %% [markdown]
# ## **Data Preprocessing**

# %% [markdown]
# Setelah memahami data melalui proses EDA, perlu dicari apakah terdapat *data duplicates*, *missing values*, *nonsensical data*, dan *outliers* pada data. Apabila terdapat aspek-aspek tersebut maka data harus ditangani yaitu sebagai berikut:

# %% [markdown]
# ### **Data Duplicates & Missing Value**

# %% [markdown]
# Pada bagian ini akan dicari adanya *data duplicates* dan *missing values*

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()/df.shape[0]*100
# Out:
# longitude             0.000000
# latitude              0.000000
# housing_median_age    0.000000
# total_rooms           0.000000
# total_bedrooms        0.948228
# population            0.000000
# households            0.000000
# median_income         0.000000
# ocean_proximity       0.000000
# median_house_value    0.000000
# dtype: float64

# %% [markdown]
# Seperti telah disebutkan, dataset tidak memiliki *data duplicates* namun memiliki *missing value* di kolom *total_bedrooms* atau jumlah kamar tidur dalam radius satu block sebanyak 0.948228% atau sekitar 0.95%.
#
# Terdapat dua cara untuk menangani *missing value*:
# * Menghapus baris / kolom yang berisi *missing value*.
# * Mengisi data yang hilang.
#
# Dikarenakan *missing value* yang terdapat dalam dataset yang diberikan hanya sebanyak 0.9%, **metode menghapus baris / kolom yang terdapat *missing value* akan jauh lebih mudah dan lebih cepat untuk dilakukan** namun terdapat resiko menghapus data atau informasi yang berharga walau kecil sehingga dalam proses *data cleaning* berikut, akan dilakukan pengecekan terlebih dahulu.

# %%
display(df[df['total_bedrooms'].isna()]['ocean_proximity'].value_counts())
# Out:
# <1H OCEAN     69
# INLAND        32
# NEAR OCEAN    24
# NEAR BAY      12
# Name: ocean_proximity, dtype: int64

# %%
display(df[df['total_bedrooms'].isna()]['median_house_value'])
# Out:
# 88        65800.0
# 119      133600.0
# 251      158700.0
# 340      146500.0
# 410       76400.0
#            ...
# 13856    150400.0
# 13932    231000.0
# 13989    221500.0
# 14308    170600.0
# 14445    289300.0
# Name: median_house_value, Length: 137, dtype: float64

# %%
display(df[df['total_bedrooms'].isna()]['total_rooms'])
# Out:
# 88       1072.0
# 119      3895.0
# 251      4427.0
# 340      2313.0
# 410       994.0
#           ...
# 13856    2093.0
# 13932    2287.0
# 13989    6347.0
# 14308    5862.0
# 14445    1431.0
# Name: total_rooms, Length: 137, dtype: float64

# %% [markdown]
# Seperti telah ditunjukkan dalam beberapa fungsi di atas, missing value yang ada tersebar ke beberapa kategori values dan tidak berada dalam satu kategori saja (misal hanya berada di kategori *ocean proximity* tertentu atau berada di rumah dengan median harga tertentu  **dapat diasumsikan bahwa apabila data dihapus, analisa data tidak terpengaruh** selain juga karena missing value hanya berjumlah 0.9%. Oleh karena itu, kita akan menghapus *missing values* dengan cara berikut ini:

# %%
df = df.dropna(axis=0)
df.isna().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# ocean_proximity       0
# median_house_value    0
# dtype: int64

# %% [markdown]
# Sebagaimana telah diperlihatkan di atas, data telah dibersihkan dari *missing values* sehingga kita dapat melanjutkan ke step berikutnya.

# %% [markdown]
# ### **Nonsensical Data**

# %% [markdown]
# Dalam bagian ini, data yang kurang masuk akal atau *nonsensical data* akan dicari dan dicoba dihilangkan. *Nonsensical data* adalah data-data yang *by nature* tidak riil dan tidak dapat terjadi, contohnya rumah dengan harga 0 atau harga negative, *median age* negative, dsb.

# %%
num_features = [feature for feature in df.columns if ((df[feature].dtypes != 'object'))]
df[num_features].describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  14311.000000  14311.000000        14311.000000  14311.000000
# mean    -119.567150     35.631365           28.609671   2640.917686
# std        2.006374      2.139589           12.606493   2197.192896
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1452.000000
# 50%     -118.490000     34.260000           29.000000   2125.000000
# 75%     -118.000000     37.715000           37.000000   3142.000000
# max     -114.310000     41.950000           52.000000  32627.000000
#
#        total_bedrooms    population    households  median_income  \
# count    14311.000000  14311.000000  14311.000000   14311.000000
# mean       538.260709   1424.772273    499.480470       3.866774
# std        423.577544   1151.795857    383.826005       1.890866
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %% [markdown]
# Dalam penjelasan seperti di atas, data-data yang tersedia tidak memiliki *nonsensical data*. Oleh karena itu, proses cleaning akan dilanjutkan ke langkah selanjutnya.

# %% [markdown]
# ### **Outliers Detection**

# %% [markdown]
# Pada bagian ini, *outliers* atau data anomali akan dicari dan dicoba untuk diminimalisir adanya agar tidak menjadikan model bias. Pada bagian sebelumnya, telah diperlihatkan dengan media visualisasi data secara singkat bahwa terdapat outliers di kolom *median house value* dan *housing median age*. Maka, pencarian *outliers* akan difokuskan ke kedua aspek tersebut terlebih dahulu.

# %%
plt.figure(figsize=(15, 5))
plt.subplot(1,2,1)
sns.distplot(df['median_house_value'])
plt.title('Median House Value Distribution Plot', size=16, weight='bold')

plt.subplot(1,2,2)
sns.boxplot(df['median_house_value'])
plt.title('Median House Value Box Plot', size=16, weight='bold')
# Out:
# Text(0.5, 1.0, 'Median House Value Box Plot')

# %%
df[df['median_house_value']>475000]['median_house_value'].value_counts().head()
# Out:
# 500001.0    672
# 500000.0     18
# 483300.0      6
# 492500.0      2
# 490800.0      2
# Name: median_house_value, dtype: int64

# %% [markdown]
# Pada aspek *median_house_value* dapat dilihat bahwa terdapat 672 data yang memiliki *value* 500001. Secara awam, hal ini cukup aneh mengingat *value* yang lain tidak memiliki jumlah data sebanyak itu. Hal ini dapat dikarenakan **pada saat melakukan sensus, pelaku sensus mengelompokkan rumah-rumah dengan harga diatas 500000 ke dalam satu kategori sehingga hanya direpresentasikan oleh value 500001**. Dalam hal ini, *value* tersebut akan dihapus untuk meminimalisir adanya bias dalam analisis.

# %%
df = df.drop(df[df['median_house_value']==500001.0].index)  
plt.figure(figsize=(6, 6))
sns.distplot(df['median_house_value'])
plt.title('Median House Value Distribution Plot After Outliers Removal', size=16, weight='bold');

# %% [markdown]
# Selanjutnya, kita akan mencari outliers di kolom *housing median age* dengan metode yang kurang lebih sama seperti di atas.

# %%
plt.figure(figsize=(8, 8))
sns.distplot(df['housing_median_age'], bins=80)
plt.title('Median House Age Distribution Plot', size=16, weight='bold');

# %%
df[df['housing_median_age']>=40]['housing_median_age'].value_counts().head()
# Out:
# 52.0    766
# 42.0    252
# 44.0    249
# 43.0    231
# 41.0    204
# Name: housing_median_age, dtype: int64

# %% [markdown]
# *Median House Age* dengan value 52 years memiliki *density* yang sangat tinggi seperti telah digambarkan pada *distplot*. Walaupun dapat dispekulasikan bahwa data tersebut ada pada titik lokasi atau koordinat old neighborhood establishment atau lingkungan yang sudah ada cukup lama, ditakutkan data-data tersebut dapat mempengaruhi analisa sehingga *values* dari *housing median age* yang sama dengan 52 tahun akan di-remove.

# %%
df = df.drop(df[df['housing_median_age']==52.0].index)  
plt.figure(figsize=(6, 6))
sns.distplot(df['housing_median_age'], bins=80)
plt.title('Median House Age Distribution Plot After Outliers Removal', size=16, weight='bold');

# %% [markdown]
# ## **Feature Selection**

# %% [markdown]
# Pada bagian ini, akan dilakukan removal salah satu feature dalam satu kategori yaitu kategori *Island* dalam fitur *Ocean Proximity* karena diasumsikan **riset ini membatasi analisa hanya untuk ruang lingkup rumah atau properti yang ada di *mainland* atau daratan utama**. Selain itu, *island houses* biasanya adalah mansion atau rumah-rumah mewah dengan harga cukup tinggi sehingga *equation* atau fungsi penentu harga tentunya akan berbeda dengan rumah-rumah di daratan.
#
# **Source: ‘Island House’ in California?** https://www.sacbee.com/news/nation-world/national/article257973843.html
#
# *Removal* feature tersebut dapat dilihat sebagai berikut:

# %%
display(df[df['ocean_proximity']=='ISLAND'])
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12680    -118.48     33.43                29.0        716.0           214.0
#
#        population  households  median_income ocean_proximity  \
# 12680       422.0       173.0         2.6042          ISLAND
#
#        median_house_value
# 12680            287500.0

# %%
display(df['ocean_proximity'].value_counts())
# Out:
# <1H OCEAN     5753
# INLAND        4410
# NEAR OCEAN    1620
# NEAR BAY      1089
# ISLAND           1
# Name: ocean_proximity, dtype: int64

# %% [markdown]
# Dikarenakan kategori *ISLAND* dalam fitur *ocean_proximity* hanya memiliki 1 data, maka juga dapat diasumsikan bahwa data tidak signifikan terhadap analisa sehingga hasil analisa tidak akan dipengaruhi. Oleh karena itu dapat langsung kita drop value tersebut.

# %%
df = df.drop(df[df['ocean_proximity']=='ISLAND'].index)

# %%
display(df['ocean_proximity'].value_counts())
# Out:
# <1H OCEAN     5753
# INLAND        4410
# NEAR OCEAN    1620
# NEAR BAY      1089
# Name: ocean_proximity, dtype: int64

# %% [markdown]
# ## **Feature Engineering**

# %% [markdown]
# Pada langkah ini, akan dilakukan *recategorization* atau *binning* terhadap fitur yang ada untuk mempertajam model regresi pada nantinya serta untuk simplifikasi kategori data.

# %% [markdown]
# ### **Binning by Median Income**
#
# Pada bagian ini, *recategorization* atau *binning* akan dilakukan terhadap *median income value* akan dilakukan.
#
# Pada tahun 2019, profesor dan *researchers* dari **George Washington University** melakukan riset dan mendapatkan kategorisasi *income group* berdasarkan *income*-nya masing masing untuk tiap *households* berisi rata rata 3 orang (ayah, ibu, dan anak) yaitu sebagai berikut:
#
# <br>
#
# | **Income Group** | **Income in Dollars** |
# | --- | --- |
# | Poor or near-poor	| 32,048 or less |
# | Lower-middle class |	32,048 - 53,413 |
# | Middle class |	53,413 - 106,827 |
# | Upper-middle class |	106,827 - 373,894 |
# | Rich | 373,894 and up |
#
# <br>
#
# Menggunakan *inflation calculator*, pada tahun 1990, standar *income group* dapat *di-scale down* menjadi seperti berikut ini:
#
# <br>
#
# | **Income Group** | **Income in Dollars** |
# | --- | --- |
# | Poor or near-poor	| 16,383 or less |
# | Lower-middle class |	16,383 - 27,306 |
# | Middle class |	27,306 - 54,613 |
# | Upper-middle class |	54,613 - 191,146 |
# | Rich | 191,146 and up |
#
# <br>
#
# Maka dari itu, kita akan coba melakukan *binning* menggunakan *standard income group category* seperti yang ada di atas.
#
# **Source: Where Do I Fall in the American Economic Class System?** https://money.usnews.com/money/personal-finance/family-finance/articles/where-do-i-fall-in-the-american-economic-class-system
#
# **CPI Inflation Calculator** https://www.in2013dollars.com/us/inflation/2019?endYear=1990&amount=373894

# %%
incomeGroup = [0, 1.6383, 2.7306, 5.4613, 19.1146, 100.0]
incomeCategory = ['Poor or near-poor', 'Lower-middle class', 'Middle class', 'Upper-middle class', 'Rich']
df['income_group'] = pd.cut(df['median_income'], bins=incomeGroup, labels=incomeCategory)
display(df['income_group'].value_counts())
# Out:
# Middle class          7205
# Lower-middle class    3237
# Upper-middle class    1711
# Poor or near-poor      719
# Rich                     0
# Name: income_group, dtype: int64

# %%
display(df.head(),df.tail())
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1    -122.21     37.77                43.0       1017.0           328.0
# 2    -118.04     33.87                17.0       2358.0           396.0
# 3    -118.28     34.06                17.0       2518.0          1196.0
# 4    -119.81     36.73                50.0        772.0           194.0
# 5    -117.79     33.80                11.0      10535.0          1620.0
#
#    population  households  median_income ocean_proximity  median_house_value  \
# 1       836.0       277.0         2.2604        NEAR BAY            100000.0
# 2      1387.0       364.0         6.2990       <1H OCEAN            285800.0
# 3      3051.0      1000.0         1.7199       <1H OCEAN            175000.0
# 4       606.0       167.0         2.2206          INLAND             59200.0
# 5      4409.0      1622.0         6.6700       <1H OCEAN            283200.0
#
#          income_group
# 1  Lower-middle class
# 2  Upper-middle class
# ...

# %% [markdown]
# ### **Binning by Housing Median Age**
#
# Pada bagian ini, *recategorization* atau *binning* akan dilakukan terhadap *housing median age* akan dilakukan.
#
# Berdasarkan kepada beberapa sumber, penulis mendapatkan kategorisasi umur bangunan rumah berdasarkan rentang umur bangunan yang dapat memungkinkan *binning* untuk dilakukan yaitu:
#
# <br>
#
# | **Housing Age Group** | **Housing Age** | **Description** |
# | --- | --- | --- |
# | New homes	| 0 - 10 years | Rumah baru, kualitas prima |
# | Minor renovation homes |	10 - 20 years | Kualitas masih baik, membutuhkan renovasi minor seperti pengecatan ulang |
# | Second renovation homes |	20 - 30 years | Kualitas mulai menurun, membutuhkan renovasi yang lebih besar seperti perawatan atap, penggantian beberapa material, dsb |
# | Major renovation homes |	30 - 40 years | Kualitas cukup rendah, membutuhkan renovasi yang besar seperti perawatan fondasi, pelapisan dinding ulang, penggantian plafon atap, dsb |
# | Old or antique homes | 40 - 50 years | Kualitas terburuk, membutuhkan renovasi besar-besaran atau bahkan pembangunan ulang

# %%
housingAgeGroup = [0, 10, 20, 30, 40, 50]
housingAgeCategory = ['New homes', 'First renovation homes', 'Second renovation homes', 'Major renovation homes', 'Old or antique homes']
df['housing_age_group'] = pd.cut(df['housing_median_age'], bins=housingAgeGroup, labels=housingAgeCategory)
display(df['housing_age_group'].value_counts())
# Out:
# Major renovation homes     3667
# Second renovation homes    3227
# First renovation homes     3193
# Old or antique homes       1680
# New homes                  1073
# Name: housing_age_group, dtype: int64

# %% [markdown]
# **Source:**
#
# *   **Determining Building Age**. https://www.nachi.org/determine-building-age.htm
# *   **Quora: Old & New Buildings**. https://www.quora.com/If-a-building-was-made-10-years-ago-would-it-be-a-new-building-or-would-it-be-an-old-building
# *   **Average Age of a House.** https://www.makaan.com/iq/buy-sell-move-property/what-is-the-average-age-of-a-house

# %% [markdown]
# # **Data Modelling**

# %% [markdown]
# Setelah memahami data, melakukan pembersihan, *serta Feature Selection & Feature Engineering*, proses *data modelling* dapat dimulai untuk menentukan model regresi mana yang dapat dijadikan acuan dan dapat menghasilkan values dengan nilai error paling kecil.dari pernyataan masalah pertama sampai dengan terakhir. Pertama-tama, kita harus melakukan import tools yang dibutuhkan terlebih dahulu.

# %%
from sklearn.model_selection import train_test_split, cross_val_score, RandomizedSearchCV, GridSearchCV, KFold

# !pip install category_encoders
import category_encoders as ce
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost.sklearn import XGBRegressor
from sklearn.compose import TransformedTargetRegressor

from sklearn.preprocessing import StandardScaler

from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# Kemudian, kita akan meng-copy *dataframe initial* untuk membuat dataframe baru yang dinamai dfModel. Dalam dfModel, *feature* atau kolom yang tidak digunakan dalam proses *modelling* akan di drop seperti pada di bawah ini:

# %%
dfModel = df.copy()
dfModel.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1    -122.21     37.77                43.0       1017.0           328.0
# 2    -118.04     33.87                17.0       2358.0           396.0
# 3    -118.28     34.06                17.0       2518.0          1196.0
# 4    -119.81     36.73                50.0        772.0           194.0
# 5    -117.79     33.80                11.0      10535.0          1620.0
#
#    population  households  median_income ocean_proximity  median_house_value  \
# 1       836.0       277.0         2.2604        NEAR BAY            100000.0
# 2      1387.0       364.0         6.2990       <1H OCEAN            285800.0
# 3      3051.0      1000.0         1.7199       <1H OCEAN            175000.0
# 4       606.0       167.0         2.2206          INLAND             59200.0
# 5      4409.0      1622.0         6.6700       <1H OCEAN            283200.0
#
#          income_group       housing_age_group
# ...

# %%
dfModel = dfModel.drop(['median_income', 'housing_median_age'], axis=1)
dfModel.head()
# Out:
#    longitude  latitude  total_rooms  total_bedrooms  population  households  \
# 1    -122.21     37.77       1017.0           328.0       836.0       277.0
# 2    -118.04     33.87       2358.0           396.0      1387.0       364.0
# 3    -118.28     34.06       2518.0          1196.0      3051.0      1000.0
# 4    -119.81     36.73        772.0           194.0       606.0       167.0
# 5    -117.79     33.80      10535.0          1620.0      4409.0      1622.0
#
#   ocean_proximity  median_house_value        income_group  \
# 1        NEAR BAY            100000.0  Lower-middle class
# 2       <1H OCEAN            285800.0  Upper-middle class
# 3       <1H OCEAN            175000.0  Lower-middle class
# 4          INLAND             59200.0  Lower-middle class
# 5       <1H OCEAN            283200.0  Upper-middle class
#
#         housing_age_group
# 1    Old or antique homes
# 2  First renovation homes
# 3  First renovation homes
# 4    Old or antique homes
# ...

# %% [markdown]
# ## **Encoding, Data Splitting, Train and Test Splitting**

# %% [markdown]
# Pada bagian ini, kita akan mengubah fitur kategorikal menjadi numerikal menggunakan One Hot Encoder. Hal ini dilakukan karena regression analysis tidak dapat dilakukan apabila di dalam data masih ada fitur fitur yang berbentuk string dan bukan value atau float.

# %%
transformer = ColumnTransformer([
    ('One Hot', OneHotEncoder(drop='first', handle_unknown='ignore'), ['ocean_proximity', 'income_group', 'housing_age_group'])
], remainder='passthrough')

# %% [markdown]
# Selanjutnya, dfModel akan dipecah menjadi database X dan Y dimana X merupakan data independen variabel dan Y merupakan target atau dependent variable.

# %%
X = dfModel.drop(['median_house_value'], axis=1)
y = dfModel['median_house_value']

# %% [markdown]
# Dalam melakukan splitting data training dan test, ditentukan proporsi 70:30 karena secara umum rasio training-dev-test 70-30 merupakan rasio paling optimal untuk dataset berukuran kecil.
#
# **Source: Data Splitting.** https://www.trivusi.web.id/2022/08/data-splitting.html

# %%
X_train, X_test, y_train, y_test= train_test_split(
    X,
    y,  
    test_size=0.3,
    random_state=1)

# %% [markdown]
# ## **Choosing a Benchmark Model**

# %% [markdown]
# Pada bagian ini, kita akan memulai *benchmarking* model untuk mencari model mana yang paling dapat merepresentasikan data kita dan dapat meminimalisir adanya error ketika melakukan prediksi kedepannya. Berikut proses-proses yang dilakukan dimulai dari mendefinisikan algoritma yang digunakan:

# %%
# Define algoritma yang digunakan
lr = LinearRegression()
knn = KNeighborsRegressor()
dt = DecisionTreeRegressor(random_state=1)
rf = RandomForestRegressor(random_state=1)
xgb = XGBRegressor(random_state=1)

# Pemodelan dilakukan dalam skala logaritmik, namun kemudian di-inverse kembali untuk interpretasi
log_lr = TransformedTargetRegressor(lr, func=np.log, inverse_func=np.exp)
log_knn = TransformedTargetRegressor(knn, func=np.log, inverse_func=np.exp)
log_dt = TransformedTargetRegressor(dt, func=np.log, inverse_func=np.exp)
log_rf = TransformedTargetRegressor(rf, func=np.log, inverse_func=np.exp)
log_xgb = TransformedTargetRegressor(xgb, func=np.log, inverse_func=np.exp)

# Scaling data
scaler = StandardScaler()

# Kandidat algoritma
models = [log_lr, log_knn, log_dt, log_rf, log_xgb]

score_rmse = []
nilai_mean_rmse = []
nilai_std_rmse = []

score_mae = []
nilai_mean_mae = []
nilai_std_mae = []

score_mape = []
nilai_mean_mape = []
nilai_std_mape = []

# Mencari algoritma terbaik berdasarkan nilai-nilai RMSE, MAE dan MAPE
for i in models:
    
    crossval = KFold(n_splits=5, shuffle=True, random_state=1)

    estimator = Pipeline([
        ('preprocessing', transformer),
        ('scaler', scaler),
        ('model', i)
    ])

    # RMSE
    model_cv_rmse = cross_val_score(
        estimator, 
        X_train, 
        y_train, 
        cv=crossval, 
        scoring='neg_root_mean_squared_error', 
        error_score='raise'
        )

    print(model_cv_rmse, i)

    score_rmse.append(model_cv_rmse)
    nilai_mean_rmse.append(model_cv_rmse.mean())
    nilai_std_rmse.append(model_cv_rmse.std())

    # MAE
    model_cv_mae = cross_val_score(
        estimator, 
        X_train, 
        y_train, 
        cv=crossval, 
        scoring='neg_mean_absolute_error', 
        error_score='raise'
        )

    print(model_cv_mae, i)

    score_mae.append(model_cv_mae)
    nilai_mean_mae.append(model_cv_mae.mean())
    nilai_std_mae.append(model_cv_mae.std())

    # MAPE
    model_cv_mape = cross_val_score(
        estimator, 
        X_train, 
        y_train, 
        cv=crossval, 
        scoring='neg_mean_absolute_percentage_error', 
        error_score='raise'
        )

    print(model_cv_mape, i)

    score_mape.append(model_cv_mape)
    nilai_mean_mape.append(model_cv_mape.mean())
    nilai_std_mape.append(model_cv_mape.std())
# Out:
# [-63650.7865123  -65999.35055727 -64160.70256173 -62519.54710573
#  -65143.05481179] TransformedTargetRegressor(func=<ufunc 'log'>, inverse_func=<ufunc 'exp'>,
#                            regressor=LinearRegression())
# [-45115.71322198 -46842.93973835 -45240.9877915  -44631.76324346
#  -46141.28974802] TransformedTargetRegressor(func=<ufunc 'log'>, inverse_func=<ufunc 'exp'>,
#                            regressor=LinearRegression())
# [-0.26219418 -0.2604047  -0.25782746 -0.25614864 -0.26031506] TransformedTargetRegressor(func=<ufunc 'log'>, inverse_func=<ufunc 'exp'>,
#                            regressor=LinearRegression())
# [-59443.11772313 -62848.52629537 -60034.66151053 -58635.02645951
#  -59553.39346974] TransformedTargetRegressor(func=<ufunc 'log'>, inverse_func=<ufunc 'exp'>,
#                            regressor=KNeighborsRegressor())
# [-41076.38878719 -42753.15141888 -41125.41097719 -40553.50620872
# ...

# %% [markdown]
# Pemodelan dilakukan dalam skala logaritmik, namun kemudian di-inverse kembali untuk interpretasi sesuai dengan sumber yang didapatkan oleh penulis.
#
# **Source**: https://machinelearningmastery.com/how-to-transform-target-variables-for-regression-with-scikit-learn/
#
# Berikut adalah evaluasi dari hasil 5 kandidat algoritma yang digunakan dalam permodelan.

# %%
pd.DataFrame({
    'Model': ['Linear Regression', 'KNN Regressor', 'DecisionTree Regressor', 'RandomForest Regressor', 'XGBoost Regressor'],
    'Mean_RMSE': nilai_mean_rmse,
    'Std_RMSE': nilai_std_rmse,
    'Mean_MAE': nilai_mean_mae,
    'Std_MAE': nilai_std_mae,
    'Mean_MAPE': nilai_mean_mape,
    'Std_MAPE': nilai_std_mape
})
# Out:
#                     Model     Mean_RMSE     Std_RMSE      Mean_MAE  \
# 0       Linear Regression -64294.688310  1200.773676 -45594.538749
# 1           KNN Regressor -60102.945092  1444.648265 -41433.922109
# 2  DecisionTree Regressor -64281.579029   653.894896 -42689.212209
# 3  RandomForest Regressor -47901.619962  1425.124536 -31555.157315
# 4       XGBoost Regressor -55193.495281  1182.225730 -37945.460008
#
#       Std_MAE  Mean_MAPE  Std_MAPE
# 0  792.294203  -0.259378  0.002131
# 1  747.012888  -0.233844  0.003451
# 2  244.974234  -0.243507  0.004170
# 3  732.918095  -0.175447  0.002524
# 4  656.473860  -0.209203  0.002823

# %% [markdown]
# Berdasarkan skor-skor yang ada di atas, kita akan memilih dua model terbaik yang memiliki skor paling mendekati 0. Dengan begitu, RandomForest Regressor dan XGBoost Regressor menjadi dua model terbaik untuk dilakukan benchmarking dan dilanjutkan ke proses selanjutnya.

# %% [markdown]
# ## **Predict to Test Set with the Benchmark Model**

# %% [markdown]
# Pada bagian ini, dua model terbaik yaitu XGB dan RandomForest akan dilakukan benchmark dan prediksi yaitu sebagai berikut:

# %%
# Benchmark 2 model terbaik
models = {
    'XGB': XGBRegressor(random_state=1),
    'RandomForest': RandomForestRegressor(random_state=1)
}

score_rmse = []
score_mae = []
score_mape = []

# Prediksi pada test set
for i in models:

    model = Pipeline([
        ('preprocessing', transformer),
        ('scaler', scaler),
        ('model', models[i])
        ])

    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    score_rmse.append(np.sqrt(mean_squared_error(y_test, y_pred)))
    score_mae.append(mean_absolute_error(y_test, y_pred))
    score_mape.append(mean_absolute_percentage_error(y_test, y_pred))

score_before_tuning = pd.DataFrame({'RMSE': score_rmse, 'MAE': score_mae, 'MAPE': score_mape}, index=models.keys())
score_before_tuning
# Out:
# [00:04:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
#                       RMSE           MAE     MAPE
# XGB           54226.623535  38542.769191  0.22753
# RandomForest  46575.143716  31033.754291  0.17920

# %% [markdown]
# Pada hasil prediksi di atas, dapat diperhatikan bahwa awalnya XGB memiliki skor error yang lebih buruh dibandingkan dengan RandomForest ditunjukkan dengan skor RMSE, MAE, dan MAPE yang lebih tinggi pada XGB dibandingkan dengan RandomForest. Namun, hyperparameter tuning akan dilakukan untuk keduanya yang akan dijelaskan di proses selanjutnya.

# %% [markdown]
# ## **Hyperparameter Tuning**

# %% [markdown]
# Hyperparameter tuning untuk XGBRegressor adalah sebagai berikut:

# %%
# Kedalaman pohon
max_depth = list(np.arange(1, 11))

# Learning rate
learning_rate = list(np.arange(1, 100)/100)

# Jumlah pohon
n_estimators = list(np.arange(100, 201))

# Jumlah baris tiap pohon (% dari total baris train set)
subsample = list(np.arange(2, 10)/10)

# Gamma (min_impurity_decrease)
gamma = list(np.arange(1, 11)) # Semakin besar nilainya, semakin konservatif/simpel modelnya

# Jumlah feature yang digunakan untuk tiap pohon (% dari total kolom train set)
colsample_bytree = list(np.arange(1, 10)/10)

# Alpha (regularization)
reg_alpha = list(np.logspace(-3, 1, 10)) # Semakin besar nilainya, semakin konservatif/simpel modelnya


# Hyperparam space XGboost
hyperparam_space_xgb = {
    'model__max_depth': max_depth, 
    'model__learning_rate': learning_rate,
    'model__n_estimators': n_estimators,
    'model__subsample': subsample,
    'model__gamma': gamma,
    'model__colsample_bytree': colsample_bytree,
    'model__reg_alpha': reg_alpha
}

# %%
# Benchmark model dengan hyperparameter tuning
xgb = XGBRegressor(random_state=1, verbosity=0)

# Membuat algorithm chains
estimator_xgb = Pipeline([
        ('preprocessing', transformer),
        ('scaler', scaler),
        ('model', xgb)
        ])

crossval = KFold(n_splits=5, shuffle=True, random_state=1)

# Hyperparameter tuning
random_xgb = RandomizedSearchCV(
    estimator_xgb, 
    param_distributions = hyperparam_space_xgb,
    n_iter = 50,
    cv = crossval, 
    scoring = ['neg_root_mean_squared_error', 'neg_mean_absolute_error', 'neg_mean_absolute_percentage_error'], 
    n_jobs = -1,
    refit = 'neg_root_mean_squared_error', # Hanya bisa memilih salah stau metric untuk optimisasi
    random_state = 1  
)

# %%
# Fitting data training untuk mencari parameter terbaik
random_xgb.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=KFold(n_splits=5, random_state=1, shuffle=True),
#                    estimator=Pipeline(steps=[('preprocessing',
#                                               ColumnTransformer(remainder='passthrough',
#                                                                 transformers=[('One '
#                                                                                'Hot',
#                                                                                OneHotEncoder(drop='first',
#                                                                                              handle_unknown='ignore'),
#                                                                                ['ocean_proximity',
#                                                                                 'income_group',
#                                                                                 'housing_age_group'])])),
# ...

# %%
# Melihat hasil tuning dalam bentuk dataframe. Diurutkan berdasarkan RMSE, MAE & MAPE
pd.DataFrame(random_xgb.cv_results_).sort_values(by=['rank_test_neg_root_mean_squared_error', 'rank_test_neg_mean_absolute_error', 'rank_test_neg_mean_absolute_percentage_error']).head()
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 7        2.407566      0.009409         0.042236        0.001113
# 20       1.527913      0.138498         0.033484        0.011658
# 8        2.287106      0.015501         0.044143        0.001344
# 43       2.127355      0.021651         0.037568        0.004576
# 17       5.140020      1.063569         0.086338        0.020512
#
#    param_model__subsample param_model__reg_alpha param_model__n_estimators  \
# 7                     0.9               0.059948                       119
# 20                    0.9               0.007743                       143
# 8                     0.7               0.021544                       182
# 43                    0.5                0.16681                       172
# 17                    0.6                  0.001                       190
#
#    param_model__max_depth param_model__learning_rate param_model__gamma  ...  \
# ...

# %%
# Cek skor dan params terbaik
print('XGBoost')
print('Best_score:', random_xgb.best_score_)
print('Best_params:', random_xgb.best_params_)
# Out:
# XGBoost
# Best_score: -45915.01654476389
# Best_params: {'model__subsample': 0.9, 'model__reg_alpha': 0.05994842503189409, 'model__n_estimators': 119, 'model__max_depth': 8, 'model__learning_rate': 0.05, 'model__gamma': 5, 'model__colsample_bytree': 0.8}

# %% [markdown]
# Hyperparameter tuning untuk model RandomForest adalah sebagai berikut:

# %%
# Hyperparam Space Random Forest

# Jumlah pohon pada random forest
n_estimators = list(np.arange(100, 201))

# Jumlah fitur yang perlu dipertimbangkan di setiap split
max_features = list(np.arange(2, 11))

# Kedalaman pohon
max_depth = list(np.arange(1, 11))

# Jumlah minimum sampel yang diperlukan untuk split sebuah node
min_samples_split = list(np.arange(2, 21))

# Jumlah minimum sampel yang diperlukan pada setiap leaf
min_samples_leaf = list(np.arange(1, 21))


hyperparam_space_rf = {
    'model__n_estimators': n_estimators,
    'model__max_features': max_features,
    'model__max_depth': max_depth,
    'model__min_samples_split': min_samples_split,
    'model__min_samples_leaf': min_samples_leaf,
}

# %%
# Model 3 dengan hyperparameter tuning
rf = RandomForestRegressor(random_state=0)

# Membuat algorithm chains
estimator_rf = Pipeline([
    ('preprocessing', transformer),
    ('scaler', scaler),
    ('model', rf)
])

crossval = KFold(n_splits=5, shuffle=True, random_state=0)

# Hyperparameter tuning
random_rf = RandomizedSearchCV(
    estimator_rf,
    param_distributions = hyperparam_space_rf,
    n_iter = 100,
    cv = crossval,
    scoring = ['neg_root_mean_squared_error', 'neg_mean_absolute_error', 'neg_mean_absolute_percentage_error'], 
    n_jobs = -1,
    refit = 'neg_root_mean_squared_error', # hanya bisa memilih satu metrik untuk optimisasi
    random_state = 1
)

# %%
random_rf.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=KFold(n_splits=5, random_state=0, shuffle=True),
#                    estimator=Pipeline(steps=[('preprocessing',
#                                               ColumnTransformer(remainder='passthrough',
#                                                                 transformers=[('One '
#                                                                                'Hot',
#                                                                                OneHotEncoder(drop='first',
#                                                                                              handle_unknown='ignore'),
#                                                                                ['ocean_proximity',
#                                                                                 'income_group',
#                                                                                 'housing_age_group'])])),
# ...

# %%
# Cek skor dan params terbaik
print('RandomForest')
print('Best_score:', random_rf.best_score_)
print('Best_params:', random_rf.best_params_)
# Out:
# RandomForest
# Best_score: -52415.20744586755
# Best_params: {'model__n_estimators': 150, 'model__min_samples_split': 4, 'model__min_samples_leaf': 13, 'model__max_features': 10, 'model__max_depth': 10}

# %% [markdown]
# ## **Predict to Test Set with the Tuned Model**

# %% [markdown]
# Berdasarkan dengan proses *hyperparameter tuning* yang telah dilakukan sebelumnya, akan dilakukan prediksi kembali ke *test set* menggunakan model yang sudah di-tune.

# %%
# Model XGBoost
model = {'XGB': XGBRegressor(random_state=1)}

# Define model terhadap estimator terbaik
xgb_tuning = random_xgb.best_estimator_

# Fitting model
xgb_tuning.fit(X_train, y_train)

# Predict test set
y_pred_xgb_tuning = xgb_tuning.predict(X_test)

# Simpan nilai metrics RMSE, MAE & MAPE setelah tuning
rmse_xgb_tuning = np.sqrt(mean_squared_error(y_test, y_pred_xgb_tuning))
mae_xgb_tuning = mean_absolute_error(y_test, y_pred_xgb_tuning)
mape_xgb_tuning = mean_absolute_percentage_error(y_test, y_pred_xgb_tuning)

score_after_tuning_xgb = pd.DataFrame({'RMSE': rmse_xgb_tuning, 'MAE': mae_xgb_tuning, 'MAPE': mape_xgb_tuning}, index=model.keys())
score_after_tuning_xgb
# Out:
#              RMSE           MAE      MAPE
# XGB  46153.120249  31283.691289  0.181887

# %%
# Model RandomForest Regressor
model = {'RF': RandomForestRegressor(random_state=1)}

# Define model terhadap estimator terbaik
rf_tuning = random_rf.best_estimator_

# Fitting model
rf_tuning.fit(X_train, y_train)

# Predict test set
y_pred_rf_tuning = rf_tuning.predict(X_test)

# Simpan nilai metrics RMSE, MAE & MAPE setelah tuning
rmse_rf_tuning = np.sqrt(mean_squared_error(y_test, y_pred_rf_tuning))
mae_rf_tuning = mean_absolute_error(y_test, y_pred_rf_tuning)
mape_rf_tuning = mean_absolute_percentage_error(y_test, y_pred_rf_tuning)

score_after_tuning_rf = pd.DataFrame({'RMSE': rmse_rf_tuning, 'MAE': mae_rf_tuning, 'MAPE': mape_rf_tuning}, index=model.keys())
score_after_tuning_rf
# Out:
#             RMSE           MAE     MAPE
# RF  52290.466812  36433.800608  0.21231

# %% [markdown]
# ## **Performance Comparison**

# %% [markdown]
# Setelah melakukan *predict to test set* dengan model yang sudah di-tune maka kita dapat membandingkan hasil *evaluation metrics* sebelum hyperparameter tuning dengan setelah hyperparameter tuning baik untuk model XGB maupun untuk RandomForest. *Evaluation metris* untuk kedua model tersebut adalah sebagai berikut:

# %%
# Sebelum hyperparameter tuning
display(pd.DataFrame(score_before_tuning.loc['XGB']).T, pd.DataFrame(score_before_tuning.loc['RandomForest']).T)
# Out:
#              RMSE           MAE     MAPE
# XGB  54226.623535  38542.769191  0.22753
#                       RMSE           MAE    MAPE
# RandomForest  46575.143716  31033.754291  0.1792

# %%
# Setelah hyperparameter tuning
display(score_after_tuning_xgb, score_after_tuning_rf)
# Out:
#              RMSE           MAE      MAPE
# XGB  46153.120249  31283.691289  0.181887
#             RMSE           MAE     MAPE
# RF  52290.466812  36433.800608  0.21231

# %% [markdown]
# Dengan memperhatikan *evaluation metrics* yang ada, XGB cenderung **memiliki error yang lebih besar daripada RandomForest sebelum proses *hyperparameter tuning*** sedangkan **setelah *proses hyperparameter tuning*, RandomForest memiliki error yang lebih besar dibandingkan XGB**.

# %%
plt.figure(figsize=(14, 8))
plot = sns.scatterplot(x=y_test, y=y_pred_xgb_tuning).set(title='Actual vs. Prediction Value', 
                                               xlabel='Actual Housing Value', 
                                               ylabel='Predicted Housing Value');

# %% [markdown]
# Grafik *scatterplot* antara *actual value* dengan *prediction value* seperti di atas menunjukkan bahwa data-data sudah cukup membentuk pola gradien yang linear yang menunjukkan bahwa *prediction value* dapat dibilang cukup mendekati *actual value* walau tidak dipungkiri masih banyak data-data yang tersebar secara acak dan jauh dari kata linear.

# %% [markdown]
# ## **Feature Importances**

# %% [markdown]
# Dalam penelitian ini, fitur-fitur yang sangat penting terhadap prediksi yang dihasilkan model dapat dilihat dalam grafik di bawah ini:

# %%
feature_imp = pd.Series(xgb_tuning['model'].feature_importances_, transformer.get_feature_names()).sort_values(ascending = False)
feature_imp.plot(kind='barh', title='Feature Importances');

# %% [markdown]
# Guna memberikan pandangan dan wawasan lebih, korelasi antar tiap tiap fitur menggunakan dummy sebagai pengganti One Hot Encoder dapat dilihat di bawah ini:

# %%
dfCorr = pd.get_dummies(dfModel, columns=['income_group', 'housing_age_group', 'ocean_proximity'])

plt.figure(figsize=(15, 12))
corrModel = dfCorr.corr(method='spearman')
sns.heatmap(corrModel, annot=True, fmt='.2f', cmap='crest', square=True, linewidths=.5)
plt.title('Correlation Matrix', size=15, weight='bold');

# %% [markdown]
# Korelasi positif antara independent variable dengan target atau dependent variable berarti semakin tinggi nilai independent variable tersebut maka akan berkontribusi positif dan semakin naik juga nilai dari dependent variable. Korelasi negatif antara independent variable dengan target atau dependent variable berarti berbanding terbalik dari korelasi positif dimana semakin tinggi nilai independent variable maka akan berkontribusi kepada semakin rendahnya nilai dependent variable, dan sebaliknya.

# %% [markdown]
# # **Conclusion & Recommendation**

# %% [markdown]
# Berdasarkan analisa dan *modelling* yang telah dilakukan sebagaimana dijelaskan di atas, dapat ditarik kesimpulan serta diformulasikannya saran dan rekomendasi. Kesimpulan dan saran yang dapat ditarik dari analisis ini adalah sebagai berikut:

# %% [markdown]
# ## **Analytical Conclusion**

# %% [markdown]
# Kesimpulan yang dapat menjawab pernyataan masalah seperti telah dijelaskan di awal penelitian ini adalah sebagai berikut:
#
# 1.   Permodelan yang sudah dilakukan dapat menjelaskan bahwa fitur '*One Hot X1 Upper-middle Class*' yang merupakan subset atau kategori dari fitur *Median Income* di *dataframe initial* adalah fitur yang paling berpengaruh terhadap 'median_house_value'. Fitur kedua yang paling berpengaruh terhadap 'median_house_value' adalah '*One Hot X0 Inland*' yang merupakan subset atau kategori dari fitur *Ocean Proximity*.
#
# 2.   Berdasarkan analisa korelasi, fitur yang paling berpengaruh pertama yaitu *One Hot X1 Upper-middle Class* berkorelasi positif dengan 'median_house_value' yang dapat diartikan bahwa sebuah lokasi akan memiliki harga rumah semakin tinggi apabila masyarakat sekitarnya adalah masyarakat Upper-Middle Class. Fitur yang paling berpengaruh kedua yaitu *One Hot X0 Inland* berkorelasi negatif terhadap target yang dapat diartikan bahwa apabila sebuah rumah berlokasi *Inland* atau jauh dari pesisir, maka harga rumah diprediksi akan turun.
#
# 3.   Metrik evaluasi yang digunakan pada model adalah nilai RMSE, MAE & MAPE. Secara perbandingan, model XGB setelah dilakukan *hyperparameter tuning* memiliki nilai metrik evaluasi yang hampir sama dibandingkan dengan model RandomForest sebelum *hyperparameter tuning*. Maka, dapat dipilih model mana saja yang dianggap representatif terhadap aktual karena jika ditinjau dari nilai MAPE yang dihasilkan oleh model-model tersebut, maka perkiraan harganya rata-rata akan meleset kurang lebih sebesar 17.9% - 18.1% dari harga seharusnya dan tidak menutup kemungkinan juga prediksinya meleset lebih jauh dari angka tersebut karena bias yang dihasilkan model masih cukup tinggi bila dilihat dari visualisasi antara value aktual dan prediksi. Walaupun begitu, MAPE dengan rentang itu cukup bagus untuk *forecasting* karena masih di rentang 10 - 25% yang mana hasil prediksi masih tergolong cukup akurat sesuai dengan sumber referensi.
#
# **Source**: https://escholarship.org/content/qt1f71t3x9/qt1f71t3x9.pdf?t=o5wul1#:~:text=A%20MAPE%20less%20than%205,in%20terms%20of%20its%20accuracy.

# %% [markdown]
# ## **Recommendation**

# %% [markdown]
# Saran dan rekomendasi yang diharapkan dapat menyelesaikan pertanyaan masalah seperti telah dijelaskan di penelitian ini adalah sebagai berikut:
#
# 1.   Melakukan update data ke kondisi yang lebih *recent* karena data yang dipakai adalah data sensus 1990 yang mungkin tingkat relevansi nya sudah sangat menurun untuk dipakai di tahun 2022 ini.
# 2.   Menambah feature atau aspek-aspek yang dapat dianalisa dan memiliki korelasi langsung seperti harga spesifik per rumah, lingkungan sekitar rumah (gated community atau general establishment), luas tanah dan bangunan dari tiap rumah, dsb.
# 3.   Diharapkan analisa dilanjutkan dengan **mempertimbangkan aspek *proximity to area of interests*** yaitu jarak relatif suatu bangunan terhadap area-area yang menjadi *atraksi* seperti **commercial center, business district, government office area, amusement park, dll** karena secara umum kedekatan terhadap area-area tersebut akan meningkatkan harga properti rumah atau bangunan.
# 4.   Dalam riset lebih lanjut, dapat dipertimbangkan untuk melakukan rekategorisasi atau binning untuk beberapa fitur lainnya yang ada contohnya **population, households** dengan dikategorikan sebagai *dense populated area*, *high density*, *low density* dan sebagainya mengingat rentang-rentang data yang ada memungkinkan untuk dilakukan binning, tentunya dengan *domain knowledge* yang lebih dalam.
# 5.   Melakukan eksplorasi terhadap model-model lainnya yang ada dan apabila memungkingkan, dapat mencari model yang khusus dibuat untuk *price regression analysis*.

# %% [markdown]
# # **Save Model**

# %%
# Save model
import pickle

estimator = Pipeline([('preprocess', transformer), ('model', XGBRegressor())])
estimator.fit(X_train, y_train)

pickle.dump(estimator, open('California-Housing-Prices-Regression-Analysis.sav', 'wb'))
# Out:
# [00:21:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
# Load model
filename = 'California-Housing-Prices-Regression-Analysis.sav'
loaded_model = pickle.load(open(filename, 'rb'))
# Out:
# [00:22:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
np.sqrt(mean_squared_error(y_test, loaded_model.predict(X_test)))
# Out:
# 54238.91579741409
